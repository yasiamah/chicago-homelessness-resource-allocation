# %% [markdown]
# # Chicago Housing Instability and Resource Allocation
#
# ## TThe Question I want to answer:
# # Chicago Housing Instability and Resource Allocation
#
# ## The Question I want to answer:
# What areas in Chicago have a dense population of homeless people, how effective is city-supported affordable housing aligned with the things that are needed, and how would priorities change under different transparent allocation scenarios?
#
# ## Important things to know
# - Housing instability is not the same as someone being homeless
# - PIT data will provide citywide context.
# - Correlation will not be presented as causation.
# - Resource allocation scenarios will be hypothetical.
#
# ## important things to know
# - Housing instability is not the same as someone being homeless
# - PIT data will provide citywide context.
# - Correlation will not be presented as causation.
# - Resource allocation scenarios will be hypothetical.

# %%
import sys

import numpy as np
import pandas as pd 
import matplotlib 
import seaborn as sns 
import plotly 

print(f"Python: {sys.version.split()[0]}")
print(f"Pandas: {pd.__version__}")
print(f"Matplotlib: {matplotlib.__version__}")
print(f"Seaborn: {sns.__version__}")
print(f"Plotly: {plotly.__version__}")
# Out:
# Python: 3.14.2
# Pandas: 3.0.6
# Matplotlib: 3.11.2
# Seaborn: 0.13.2
# Plotly: 7.1.0
